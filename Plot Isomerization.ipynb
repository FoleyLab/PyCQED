# %%
from matplotlib import cm
from matplotlib import rcParams
from matplotlib import pyplot as plt
import numpy as np
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 14

fig, ax = plt.subplots(constrained_layout=True)
x = np.array([10, 20, 30, 40, 45, 50, 55,  70, 75, 80, 85, 90, 95])
y = np.array([0.88, 0.56, 0.74, 0.54, 0.78, 0.78, 0.78, 0.62, 0.52, 0.26, 0.04, 0, 0])


ax.plot(x, y, 'o-', color='blue', label = 'Trans')
ax.plot(x, 1-y, 'o-',  color='red', label = 'Cis')
ax.set_xlabel('$\hbar \gamma$ (meV)')
ax.set_ylabel('Isomerization Rate')
ax.set_ylim(0,1.2)
ax.legend()
plt.savefig("Isomerization.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
